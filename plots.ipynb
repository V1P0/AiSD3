# %%
# %matplotlib widget
import functions as f
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import random
import tqdm

# %%
ns = [100*i for i in range(1, 101)]
results_c = [[0 for _ in range(100)] for _ in range(100)]
results_s = [[0 for _ in range(100)] for _ in range(100)]
m = 100
for i in tqdm.tqdm(range(100)):
    for j in range(100):
        for _ in range(m):
            arr = [random.randint(0, 2*ns[i]-1) for _ in range(ns[i])]
            k = ns[i]//100*j
            a, c, s = f.select(arr, k)
            results_c[i][j] += c
            results_s[i][j] += s
        results_c[i][j] /= m
        results_s[i][j] /= m
# Out:
# 100%|██████████| 100/100 [3:05:30<00:00, 111.30s/it]

# %%
x = []
y = []
zc = []
zs = []
for i in range(100):
    for j in range(100):
        x.append(ns[i])
        y.append(j+1)
        zc.append(results_c[i][j])
        zs.append(results_s[i][j])

# %%
# creating figure
fig = plt.figure()
ax = Axes3D(fig)

# creating the plot
plot_c = ax.plot_trisurf(x, y, zc, cmap=plt.cm.jet)

# setting title and labels
ax.set_title("Select")
ax.set_xlabel('n')
ax.set_ylabel('k')
ax.set_zlabel('comparisons')

# displaying the plot
plt.show()
# Out:
# C:\Users\oem\AppData\Local\Temp\ipykernel_18564\773443869.py:3: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# creating figure
fig = plt.figure()
ax = Axes3D(fig)

# creating the plot
plot_s = ax.plot_trisurf(x, y, zs, cmap=plt.cm.jet)

# setting title and labels
ax.set_title("Select")
ax.set_xlabel('n')
ax.set_ylabel('k')
ax.set_zlabel('swaps')

# displaying the plot
plt.show()
# Out:
# C:\Users\oem\AppData\Local\Temp\ipykernel_18564\3224241835.py:3: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
with open('results_select.csv', 'w') as f:
    for i in range(len(x)):
        f.write(str(x[i]) + ',' + str(y[i]) + ',' + str(zc[i]) + ',' + str(zs[i]) + '\n')

# %%
results_c_2 = [[0 for _ in range(100)] for _ in range(100)]
results_s_2 = [[0 for _ in range(100)] for _ in range(100)]
m = 100
for i in tqdm.tqdm(range(100)):
    for j in range(100):
        for _ in range(m):
            arr = [random.randint(0, 2*ns[i]-1) for _ in range(ns[i])]
            k = ns[i]//100*j
            a, c, s = f.random_select(arr, k)
            results_c_2[i][j] += c
            results_s_2[i][j] += s
        results_c_2[i][j] /= m
        results_s_2[i][j] /= m
# Out:
# 100%|██████████| 100/100 [3:08:08<00:00, 112.89s/it]

# %%
x = []
y = []
zc = []
zs = []
for i in range(100):
    for j in range(100):
        x.append(ns[i])
        y.append(j+1)
        zc.append(results_c_2[i][j])
        zs.append(results_s_2[i][j])

# %%
# creating figure
fig = plt.figure()
ax = Axes3D(fig)

# creating the plot
plot_c = ax.plot_trisurf(x, y, zc, cmap=plt.cm.jet)

# setting title and labels
ax.set_title("Rand Select")
ax.set_xlabel('n')
ax.set_ylabel('k')
ax.set_zlabel('comparisons')

# displaying the plot
plt.show()
# Out:
# C:\Users\oem\AppData\Local\Temp\ipykernel_18564\1064587076.py:3: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# creating figure
fig = plt.figure()
ax = Axes3D(fig)

# creating the plot
plot_s = ax.plot_trisurf(x, y, zs, cmap=plt.cm.jet)

# setting title and labels
ax.set_title("Rand Select")
ax.set_xlabel('n')
ax.set_ylabel('k')
ax.set_zlabel('swaps')

# displaying the plot
plt.show()
# Out:
# C:\Users\oem\AppData\Local\Temp\ipykernel_18564\3646047868.py:3: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
with open('results_select_random.csv', 'w') as f:
    for i in range(len(x)):
        f.write(str(x[i]) + ',' + str(y[i]) + ',' + str(zc[i]) + ',' + str(zs[i]) + '\n')
